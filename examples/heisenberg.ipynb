# %% [markdown]
# # MC simulation of the Heisenberg model

# %%
import sys
import os
import numpy as np
import random
import yaml
import pprint

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('..') #/Users/l2v/work/pyember/

# %% [markdown]
# Import kmc simulation tools

# %%
pwd
# Out:
# '/Users/l2v/work/pyember/examples'

# %%
from pyember.buildtools import make_heisenberg
from pyember.io import read_xyz, write_xyz
from pyember.simulation import Simulation

# %% [markdown]
# Working directory (inputs, outputs)

# %%
wdir = './data/working'

# %% [markdown]
# Set up simulation box and initial configuration of the substrate (with atoms filling the whole box)

# %%
# make substrate: perfect FCC lattice of given dimensions
box = [8, 8, 8]
config = make_heisenberg(dims=box)

# %%
write_xyz(config, os.path.join(wdir, 'heis.xyz'))

# %%
param_file = os.path.join(wdir, 'control.yml')
with open(param_file, 'r') as f:
    params = yaml.safe_load(f)
    
pprint.pprint(params)
# Out:
# {'config': {'file': './data/working/heis.xyz',
#             'latt_box': [8, 8, 8],
#             'pbc': [1, 1, 1],
#             'type': 'SC_n3'},
#  'hamilton': {'params': {'H': [0.0, 0.0, 1.0], 'J': 1.0, 'Temp': 0.2},
#               'type': 'heisenberg'},
#  'moves': {'spin_flip_3d': 1.0},
#  'sim_type': 'MMC',
#  'time_control': {'measure': 1000,
#                   'print': 1000,
#                   'save': 1000,
#                   'total': 100000}}

# %%
sim = Simulation(param_file)
# Out:
# types <class 'method'> <class 'method'>

# %%
sim.run()
# Out:
# time, total_energy, |M|, Mx, My, Mz
# 0.0 -26.114969860148967 14.0 5.0 6.0 -12.0
# 1001.0 -366.0265437257981 20.0 -7.0 -6.0 18.0
# 2002.0 -500.1208577125729 27.0 -5.0 5.0 26.0
# 3003.0 -599.7628042659852 24.0 -9.0 2.0 22.0
# 4004.0 -690.0678974587747 19.0 -6.0 2.0 18.0
# 5005.0 -736.527983200078 22.0 -8.0 -8.0 19.0
# 6006.0 -771.4184123449475 21.0 3.0 2.0 21.0
# 7007.0 -815.1731980564522 21.0 3.0 -4.0 20.0
# 8008.0 -863.9098156211089 19.0 1.0 -11.0 15.0
# 9009.0 -902.0138272184353 18.0 6.0 -12.0 13.0
# 10010.0 -934.8240142856446 19.0 3.0 -12.0 14.0
# 11011.0 -962.2035692746246 20.0 -2.0 -7.0 19.0
# 12012.0 -983.1193665093765 26.0 -7.0 -4.0 25.0
# 13013.0 -1015.6311319802275 28.0 -10.0 -4.0 26.0
# 14014.0 -1040.5508966794346 21.0 0.0 -4.0 21.0
# 15015.0 -1056.2387285275872 25.0 6.0 -14.0 20.0
# 16016.0 -1076.6989107625725 27.0 2.0 -10.0 25.0
# 17017.0 -1091.0761257259646 26.0 6.0 -4.0 25.0
# 18018.0 -1105.3229144691134 24.0 3.0 -5.0 23.0
# 19019.0 -1124.6467778281767 25.0 -2.0 -5.0 25.0
# 20020.0 -1133.317035448283 29.0 -6.0 -8.0 27.0
# 21021.0 -1150.6689213644086 26.0 -8.0 -8.0 23.0
# 22022.0 -1157.6548733012742 28.0 -6.0 -13.0 24.0
# 23023.0 -1173.2439962226754 23.0 -8.0 -8.0 20.0
# 24024.0 -1182.9520264514888 17.0 1.0 -4.0 16.0
# 25025.0 -1176.5571536994225 19.0 -2.0 -2.0 18.0
# 26026.0 -1182.5392317908884 17.0 3.0 -3.0 16.0
# 27027.0 -1178.4393140630534 19.0 -5.0 -2.0 18.0
# 28028.0 -1184.3949855011492 22.0 -6.0 -5.0 21.0
# 29029.0 -1186.1482051591959 22.0 -6.0 -2.0 21.0
# 30030.0 -1195.0724087757767 19.0 -5.0 -3.0 18.0
# 31031.0 -1201.2379293667468 18.0 -6.0 0.0 17.0
# 32032.0 -1202.9716145119196 19.0 -8.0 0.0 17.0
# 33033.0 -1212.4426699059022 14.0 -2.0 1.0 14.0
# 34034.0 -1224.8502677616748 13.0 -1.0 3.0 12.0
# 35035.0 -1222.5875264979409 15.0 0.0 -3.0 15.0
# 36036.0 -1222.638234088666 17.0 -6.0 1.0 16.0
# 37037.0 -1233.8415634700434 17.0 -8.0 4.0 14.0
# 38038.0 -1234.3469839820427 17.0 -7.0 -1.0 15.0
# 39039.0 -1227.3882531056936 18.0 0.0 -3.0 17.0
# 40040.0 -1226.741335364604 21.0 -0.0 -3.0 21.0
# 41041.0 -1224.4360997928636 23.0 0.0 -1.0 23.0
# 42042.0 -1227.9456664710092 20.0 4.0 1.0 20.0
# 43043.0 -1227.3660450753246 25.0 7.0 0.0 24.0
# 44044.0 -1226.8010751421373 28.0 4.0 -3.0 27.0
# 45045.0 -1234.541175743271 24.0 1.0 -1.0 24.0
# 46046.0 -1239.3882368572936 20.0 4.0 1.0 20.0
# 47047.0 -1250.279540116231 17.0 4.0 1.0 16.0
# 48048.0 -1252.1691167718966 16.0 6.0 3.0 15.0
# 49049.0 -1245.5427995629868 17.0 6.0 2.0 16.0
# 50050.0 -1245.037123782403 19.0 3.0 5.0 18.0
# 51051.0 -1252.5343438338946 20.0 4.0 3.0 20.0
# 52052.0 -1249.7753466157108 21.0 5.0 -4.0 20.0
# 53053.0 -1256.4913702665506 20.0 1.0 -2.0 19.0
# 54054.0 -1269.9543280552068 16.0 -1.0 2.0 16.0
# 55055.0 -1264.0033210759552 21.0 -11.0 2.0 17.0
# 56056.0 -1260.4253245108246 23.0 -13.0 3.0 19.0
# 57057.0 -1256.5219265453711 22.0 -10.0 4.0 18.0
# 58058.0 -1251.4670846586628 25.0 -11.0 -0.0 22.0
# 59059.0 -1254.667230596699 24.0 -10.0 2.0 21.0
# 60060.0 -1259.4196373088232 23.0 -10.0 1.0 20.0
# 61061.0 -1258.1369952216567 20.0 -5.0 0.0 20.0
# 62062.0 -1256.8613019013098 21.0 -2.0 -3.0 21.0
# 63063.0 -1258.6607526305581 24.0 -1.0 -2.0 24.0
# 64064.0 -1264.9483236001556 20.0 1.0 -1.0 20.0
# 65065.0 -1273.298761204734 16.0 -0.0 1.0 16.0
# 66066.0 -1270.9570549114626 18.0 1.0 -1.0 18.0
# 67067.0 -1275.2825390711337 17.0 0.0 -0.0 17.0
# 68068.0 -1280.8031804037785 16.0 3.0 -1.0 16.0
# 69069.0 -1288.760272622142 15.0 8.0 1.0 12.0
# 70070.0 -1287.1023170822825 15.0 0.0 6.0 14.0
# 71071.0 -1289.117818422545 16.0 -0.0 2.0 15.0
# 72072.0 -1283.613789638849 16.0 -1.0 -0.0 16.0
# 73073.0 -1280.7041493630854 14.0 3.0 1.0 14.0
# 74074.0 -1279.1764249264131 15.0 7.0 -1.0 13.0
# 75075.0 -1282.5242526511945 14.0 1.0 5.0 13.0
# 76076.0 -1282.550041685759 14.0 3.0 0.0 13.0
# 77077.0 -1283.868884826462 17.0 4.0 -5.0 16.0
# 78078.0 -1287.40915706979 19.0 10.0 -7.0 14.0
# 79079.0 -1277.1491118608485 19.0 7.0 -3.0 17.0
# 80080.0 -1280.4668720705488 16.0 5.0 -1.0 15.0
# 81081.0 -1281.1963305207198 19.0 13.0 -0.0 14.0
# 82082.0 -1275.5518996697149 18.0 8.0 1.0 16.0
# 83083.0 -1274.2152884173838 20.0 3.0 2.0 19.0
# 84084.0 -1269.3973005159237 24.0 10.0 -4.0 22.0
# 85085.0 -1273.7303223872882 26.0 8.0 -9.0 23.0
# 86086.0 -1282.2714986106243 20.0 6.0 -3.0 18.0
# 87087.0 -1282.7870094161694 20.0 -3.0 4.0 20.0
# 88088.0 -1282.8441843530625 18.0 -6.0 5.0 17.0
# 89089.0 -1280.4177806326811 21.0 -10.0 5.0 17.0
# 90090.0 -1282.6724181356667 19.0 -7.0 4.0 17.0
# 91091.0 -1273.7381743400529 20.0 -1.0 1.0 20.0
# 92092.0 -1287.379669643929 17.0 5.0 2.0 16.0
# 93093.0 -1280.5410206906986 18.0 6.0 -1.0 18.0
# 94094.0 -1286.6298291016396 19.0 2.0 3.0 19.0
# 95095.0 -1275.324423961419 24.0 -1.0 3.0 24.0
# 96096.0 -1276.3215203437312 23.0 4.0 1.0 23.0
# 97097.0 -1285.05591037641 21.0 7.0 8.0 18.0
# 98098.0 -1296.907646680171 17.0 1.0 6.0 16.0
# 99099.0 -1296.0925352840593 20.0 9.0 -2.0 18.0
# End of simulation
